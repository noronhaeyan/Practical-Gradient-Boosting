# %% [markdown]
# # Import Packages

# %%
from tsfresh import extract_features
from tsfresh.feature_extraction.settings import MinimalFCParameters
import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# In the implementation of tsfresh.feature_extraction.settings, MinimalFCParameters extends ComprehensiveFCParameters and only retains those params whose attributes have the flag minimal

# %% [markdown]
# # Time series creation

# %%
monthly_variation = [0.0, 0.0, 0.0, 0.01, 0.05, 0.1, 0.2, 0.5, 0.4, 0.2, 0.05, 0.0]
weekly_sales = [20, 25, 30, 25, 20, 30, 0]
constant_sales = [10, 10, 10, 10, 10, 10, 10]

# %%
product_0 = pd.DataFrame({'date': pd.date_range(start = '01/04/2021', end = '01/02/2022'),
                          'value': np.array(weekly_sales * 52) + np.random.normal(0,2,364),
                         'unique_id': [0]*364})

# %%
product_1 = pd.DataFrame({'date': pd.date_range(start = '01/04/2021', end = '01/02/2022'),
                          'value': np.array(constant_sales * 52) + np.random.normal(0,2,364),
                         'unique_id': [1]*364})

# %%
product_2 = pd.DataFrame({'date': pd.date_range(start = '01/04/2021', end = '01/02/2022'),
                          'value': np.array(weekly_sales * 52) + np.random.normal(0,2,364),
                         'unique_id': [2]*364})

# %%
product_3 = pd.DataFrame({'date': pd.date_range(start = '01/04/2021', end = '01/02/2022'),
                          'value': np.array(constant_sales * 52) + np.random.normal(0,2,364),
                         'unique_id': [3]*364})

# %% [markdown]
# Product 0 and 1 will be the training data and product 2 and 3 will be the test data for weekly varying and constant sales respectively.

# %%
X = pd.concat([product_0, product_1])

# %%
test = pd.concat([product_2, product_3])

# %% [markdown]
# Extract features using the tsfresh package

# %%
features = extract_features(timeseries_container = X,
                           column_id = 'unique_id',
                           column_value = 'value',
                           column_sort = 'date',
                           default_fc_parameters = MinimalFCParameters())
# Out:
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 2/2 [00:03<00:00,  1.62s/it]

# %%
features
# Out:
#    value__sum_values  value__median  value__mean  value__length  \
# 0        7813.117427      24.060229    21.464608          364.0
# 1        3629.251640       9.891223     9.970472          364.0
#
#    value__standard_deviation  value__variance  value__root_mean_square  \
# 0                   9.752139        95.104210                23.576124
# 1                   1.969193         3.877719                10.163071
#
#    value__maximum  value__absolute_maximum  value__minimum
# 0       34.991762                34.991762       -3.988635
# 1       15.242831                15.242831        4.640510

# %%
features = features.rename_axis('unique_id').reset_index()

# %%
X = X.merge(features, on = 'unique_id')
X.head()
# Out:
#         date      value  unique_id  value__sum_values  value__median  \
# 0 2021-01-04  20.446972          0        7813.117427      24.060229
# 1 2021-01-05  24.933529          0        7813.117427      24.060229
# 2 2021-01-06  26.406647          0        7813.117427      24.060229
# 3 2021-01-07  24.667227          0        7813.117427      24.060229
# 4 2021-01-08  17.722797          0        7813.117427      24.060229
#
#    value__mean  value__length  value__standard_deviation  value__variance  \
# 0    21.464608          364.0                   9.752139         95.10421
# 1    21.464608          364.0                   9.752139         95.10421
# 2    21.464608          364.0                   9.752139         95.10421
# 3    21.464608          364.0                   9.752139         95.10421
# 4    21.464608          364.0                   9.752139         95.10421
#
#    value__root_mean_square  value__maximum  value__absolute_maximum  \
# 0                23.576124       34.991762                34.991762
# 1                23.576124       34.991762                34.991762
# 2                23.576124       34.991762                34.991762
# 3                23.576124       34.991762                34.991762
# 4                23.576124       34.991762                34.991762
#
#    value__minimum
# 0       -3.988635
# 1       -3.988635
# 2       -3.988635
# 3       -3.988635
# 4       -3.988635

# %%
X['day_of_week'] = X['date'].apply(lambda x: x.day_of_week)
X.head()
# Out:
#         date      value  unique_id  value__sum_values  value__median  \
# 0 2021-01-04  20.446972          0        7813.117427      24.060229
# 1 2021-01-05  24.933529          0        7813.117427      24.060229
# 2 2021-01-06  26.406647          0        7813.117427      24.060229
# 3 2021-01-07  24.667227          0        7813.117427      24.060229
# 4 2021-01-08  17.722797          0        7813.117427      24.060229
#
#    value__mean  value__length  value__standard_deviation  value__variance  \
# 0    21.464608          364.0                   9.752139         95.10421
# 1    21.464608          364.0                   9.752139         95.10421
# 2    21.464608          364.0                   9.752139         95.10421
# 3    21.464608          364.0                   9.752139         95.10421
# 4    21.464608          364.0                   9.752139         95.10421
#
#    value__root_mean_square  value__maximum  value__absolute_maximum  \
# 0                23.576124       34.991762                34.991762
# 1                23.576124       34.991762                34.991762
# 2                23.576124       34.991762                34.991762
# 3                23.576124       34.991762                34.991762
# 4                23.576124       34.991762                34.991762
#
#    value__minimum  day_of_week
# 0       -3.988635            0
# 1       -3.988635            1
# 2       -3.988635            2
# 3       -3.988635            3
# 4       -3.988635            4

# %%
features = extract_features(timeseries_container = test,
                           column_id = 'unique_id',
                           column_value = 'value',
                           column_sort = 'date',
                           default_fc_parameters = MinimalFCParameters())

features = features.rename_axis('unique_id').reset_index()
test = test.merge(features, on = 'unique_id')
test['day_of_week'] = test['date'].apply(lambda x: x.day_of_week)
test.head()
# Out:
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 2/2 [00:03<00:00,  1.62s/it]
#         date      value  unique_id  value__sum_values_x  value__median_x  \
# 0 2021-01-04  19.237755          2          7830.947806        23.823858
# 1 2021-01-05  26.128039          2          7830.947806        23.823858
# 2 2021-01-06  31.066775          2          7830.947806        23.823858
# 3 2021-01-07  28.818512          2          7830.947806        23.823858
# 4 2021-01-08  19.938313          2          7830.947806        23.823858
#
#    value__mean_x  value__length_x  value__standard_deviation_x  \
# 0      21.513593            364.0                     9.844854
# 1      21.513593            364.0                     9.844854
# 2      21.513593            364.0                     9.844854
# 3      21.513593            364.0                     9.844854
# 4      21.513593            364.0                     9.844854
#
#    value__variance_x  value__root_mean_square_x  ...  value__sum_values  \
# 0          96.921145                  23.659159  ...        7830.947806
# 1          96.921145                  23.659159  ...        7830.947806
# 2          96.921145                  23.659159  ...        7830.947806
# 3          96.921145                  23.659159  ...        7830.947806
# 4          96.921145                  23.659159  ...        7830.947806
#
#    value__median  value__mean  value__length  value__standard_deviation  \
# 0      23.823858    21.513593          364.0                   9.844854
# 1      23.823858    21.513593          364.0                   9.844854
# 2      23.823858    21.513593          364.0                   9.844854
# 3      23.823858    21.513593          364.0                   9.844854
# 4      23.823858    21.513593          364.0                   9.844854
#
#    value__variance  value__root_mean_square  value__maximum  \
# 0        96.921145                23.659159       35.241459
# 1        96.921145                23.659159       35.241459
# 2        96.921145                23.659159       35.241459
# 3        96.921145                23.659159       35.241459
# 4        96.921145                23.659159       35.241459
#
#    value__absolute_maximum  value__minimum
# 0                35.241459       -3.654935
# 1                35.241459       -3.654935
# 2                35.241459       -3.654935
# 3                35.241459       -3.654935
# 4                35.241459       -3.654935
#
# [5 rows x 34 columns]

# %% [markdown]
# # Training

# %%
def train_and_predict(flist, test_set):
    train_data = lgb.Dataset(X[flist], label = X['value'])
    model = lgb.train({}, train_data)
    pred = model.predict(test_set[flist])
    
    return pred

# %%
feature_list = features.columns.to_list() + ['day_of_week']

pred = train_and_predict(feature_list, test[test['unique_id'] == 2])
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36
# [LightGBM] [Info] Number of data points in the train set: 728, number of used features: 11
# [LightGBM] [Info] Start training from score 15.717540
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(pred[:7])
print(test['value'][test['unique_id'] == 2].to_list()[:7])
# Out:
# [10.22829098  9.47956852  9.91327795  9.90118681  9.80190599 10.41837645
#  10.05176254]
# [19.23775549139016, 26.12803859259153, 31.06677474489474, 28.818511745910744, 19.938313404275373, 32.08586000840996, 0.30925257987842336]

# %%
pred = train_and_predict(feature_list, test[test['unique_id'] == 3])
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000050 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 36
# [LightGBM] [Info] Number of data points in the train set: 728, number of used features: 11
# [LightGBM] [Info] Start training from score 15.717540
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(pred[:7])
print(test[test['unique_id'] == 3]['value'].to_list()[:7])
# Out:
# [10.22829098  9.47956852  9.91327795  9.90118681  9.80190599 10.41837645
#  10.05176254]
# [7.727262192382208, 9.105461999810144, 10.970659371222489, 9.40033103388227, 9.887822956883964, 7.6760717400737635, 8.989685424363786]
